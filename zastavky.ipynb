# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import csv
with open('/home/mj/w/protab-scipy/data/zastavky.csv') as z:
    zast = list(csv.reader(z, delimiter=';'))

# %%
zastp = [r for r in zast if r[1] == 'Praha']
east=[float(r[3]) for r in zastp]
north=[float(r[4]) for r in zastp]

# %%
plt.plot(north, east, 'ro')
plt.show()
